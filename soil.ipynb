# %% [markdown]
# <a href="https://colab.research.google.com/github/kjxeez/study-practice/blob/main/soil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("/content/data-49155-2023-06-05.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.drop(index=0, inplace=True)

# %%
df
# Out:
#          ID  Year   global_id                                 AdmArea  \
# 1       539  2017   857110701      Центральный административный округ
# 2       643  2017   857122923    Юго-Восточный административный округ
# 3      6150  2020  1088680720   Зеленоградский административный округ
# 4      6907  2021  2305223233    Юго-Восточный административный округ
# 5      7116  2021  2305223169  Северо-Западный административный округ
# ...     ...   ...         ...                                     ...
# 996   10245  2022  2591766892            Южный административный округ
# 997   10110  2022  2591766902            Южный административный округ
# 998   10094  2022  2591766912            Южный административный округ
# 999     299  2016   477541192         Северный административный округ
# 1000    765  2017   857259172  Северо-Западный административный округ
#
#                      District  \
# 1             Басманный район
# 2             район Лефортово
# 3                район Силино
# ...

# %% [markdown]
# # __EDA__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1 to 1000
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   1000 non-null   object
#  1   Year                 1000 non-null   object
#  2   global_id            1000 non-null   object
#  3   AdmArea              1000 non-null   object
#  4   District             1000 non-null   object
#  5   Address              1000 non-null   object
#  6   EstimatedindexValue  1000 non-null   object
#  7   PollutionCategory    1000 non-null   object
#  8   PollutionLevel       1000 non-null   object
# dtypes: object(9)
# memory usage: 70.4+ KB
